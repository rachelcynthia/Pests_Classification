# %% [markdown]
# <a href="https://colab.research.google.com/github/rachelcynthia/Pests_Identification/blob/main/Database_Creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Working with one image (sample)

# %%
import PIL
from PIL import Image
from numpy import asarray
import pandas as pd

# %% [markdown]
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# ```
# Mounted at /content/drive

# %% [markdown]
# Open Image using Pillow

# %%
insect = 'aphid'
i=1
img = Image.open(r'/content/drive/MyDrive/Pests Dataset/train/' + insect + '/' + str(1) + '.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225 at 0x7F8EEDE6B080>

# %% [markdown]
# Convert Image to data and store as 2d array

# %%
data = asarray(img)
data = data.reshape(data.shape[0],-1)
data
data.shape
# Out:
# (225, 675)

# %% [markdown]
# Creating a Dataframe to store the arrays

# %%
l1=["aphid","caterpillar"]
l2 =[0,1]
df = pd.DataFrame({'label' : l1,'image':l2})
df
# Out:
#          label  image
# 0        aphid      0
# 1  caterpillar      1

# %% [markdown]
# Converting DataFrame to .csv file

# %%
df.to_csv('file1.csv')

# %% [markdown]
# # Saving the csv file for all training set images

# %%
class_names = ["aphid","caterpillar","cutworm","earheadbug","leafhopper","locust","mites","slaters","stemborer","thrips","weevil","whitefly"]
images_array = []
labels_array = []
for i in range(len(class_names)):
  for j in range(15):
    img = Image.open(r'/content/drive/MyDrive/Pests Dataset/train/' + class_names[i] + '/' + str(j+1) + '.jpg')
    data = asarray(img)
    data = data.reshape(data.shape[0],-1)
    images_array.append(data)
    labels_array.append(class_names[i])
labels_array
# Out:
# ['aphid',
#  'aphid',
#  'aphid',
#  'aphid',
#  'aphid',
#  'aphid',
#  'aphid',
#  'aphid',
#  'aphid',
#  'aphid',
#  'aphid',
#  'aphid',
#  'aphid',
#  'aphid',
#  'aphid',
#  'caterpillar',
#  'caterpillar',
#  'caterpillar',
#  'caterpillar',
#  'caterpillar',
#  'caterpillar',
#  'caterpillar',
#  'caterpillar',
#  'caterpillar',
#  'caterpillar',
#  'caterpillar',
#  'caterpillar',
#  'caterpillar',
#  'caterpillar',
#  'caterpillar',
#  'cutworm',
#  'cutworm',
#  'cutworm',
#  'cutworm',
#  'cutworm',
#  'cutworm',
#  'cutworm',
#  'cutworm',
#  'cutworm',
#  'cutworm',
#  'cutworm',
#  'cutworm',
#  'cutworm',
#  'cutworm',
#  'cutworm',
#  'earheadbug',
#  'earheadbug',
#  'earheadbug',
#  'earheadbug',
#  'earheadbug',
#  'earheadbug',
#  'earheadbug',
#  'earheadbug',
#  'earheadbug',
#  'earheadbug',
#  'earheadbug',
#  'earheadbug',
#  'earheadbug',
#  'earheadbug',
#  'earheadbug',
#  'leafhopper',
#  'leafhopper',
#  'leafhopper',
#  'leafhopper',
#  'leafhopper',
# ...

# %% [markdown]
# Save the training set as a .csv file

# %%
dataset = pd.DataFrame({'labels': labels_array, 'image': images_array})
dataset.to_csv('training_set.csv')

# %% [markdown]
# # Doing the same technique for Test Set Images

# %%
class_names = ["aphid","caterpillar","cutworm","earheadbug","leafhopper","locust","mites","slaters","stemborer","thrips","weevil","whitefly"]
images_array = []
labels_array = []
for i in range(len(class_names)):
  for j in range(5):
    img = Image.open(r'/content/drive/MyDrive/Pests Dataset/test/' + class_names[i] + '/' + str(j+1) + '.jpg')
    data = asarray(img)
    data = data.reshape(data.shape[0],-1)
    images_array.append(data)
    labels_array.append(class_names[i])
labels_array
# Out:
# ['aphid',
#  'aphid',
#  'aphid',
#  'aphid',
#  'aphid',
#  'caterpillar',
#  'caterpillar',
#  'caterpillar',
#  'caterpillar',
#  'caterpillar',
#  'cutworm',
#  'cutworm',
#  'cutworm',
#  'cutworm',
#  'cutworm',
#  'earheadbug',
#  'earheadbug',
#  'earheadbug',
#  'earheadbug',
#  'earheadbug',
#  'leafhopper',
#  'leafhopper',
#  'leafhopper',
#  'leafhopper',
#  'leafhopper',
#  'locust',
#  'locust',
#  'locust',
#  'locust',
#  'locust',
#  'mites',
#  'mites',
#  'mites',
#  'mites',
#  'mites',
#  'slaters',
#  'slaters',
#  'slaters',
#  'slaters',
#  'slaters',
#  'stemborer',
#  'stemborer',
#  'stemborer',
#  'stemborer',
#  'stemborer',
#  'thrips',
#  'thrips',
#  'thrips',
#  'thrips',
#  'thrips',
#  'weevil',
#  'weevil',
#  'weevil',
#  'weevil',
#  'weevil',
#  'whitefly',
#  'whitefly',
#  'whitefly',
#  'whitefly',
#  'whitefly']

# %% [markdown]
# Save the test set to a .csv file

# %%
dataset = pd.DataFrame({'labels': labels_array, 'image': images_array})
dataset.to_csv('test_set.csv')
